# %% [markdown]
# Tasks - Linear Algebra 1 (Easy)
#
# Work through each task in order. Fill in the code where you see None.
# Topics: scalars, vectors, matrices, basic operations, transpose, dot product,
# element-wise ops, reshape, norms, and matrix multiplication.
#
# Run each cell after completing it to check your answer.

# %% [markdown]
# Task 1 - Scalars
#
# Create two scalars and perform basic arithmetic on them.
# A scalar is a single number, the simplest object in linear algebra.

# %%
import numpy as np

# create scalar a = 7.0 and b = 3.0
a = None  # your code here
b = None  # your code here

result_sum  = None  # a + b
result_diff = None  # a - b
result_prod = None  # a * b
result_div  = None  # a / b
result_pow  = None  # a ** 2

print(f'a + b  = {result_sum}')
print(f'a - b  = {result_diff}')
print(f'a * b  = {result_prod}')
print(f'a / b  = {result_div}')
print(f'a ** 2 = {result_pow}')

# %% [markdown]
# Task 2 - Vectors
#
# Create a vector and access its elements.
# Vectors are 1D ordered collections of numbers used to represent data points and features.

# %%
import numpy as np

# create a vector with values [2, 5, 8, 11, 14]
v = None  # your code here

first  = None  # first element (index 0)
last   = None  # last element
middle = None  # elements at index 1, 2, 3 (use a slice)

print(f'vector : {v}')
print(f'first  : {first}')
print(f'last   : {last}')
print(f'middle : {middle}')
print(f'shape  : {v.shape}')
print(f'dtype  : {v.dtype}')

# %% [markdown]
# Task 3 - Matrices
#
# Create a 2D matrix and access rows, columns, and individual elements.
# A matrix organises numbers in rows and columns, forming the backbone of linear algebra.

# %%
import numpy as np

# create a 3x3 matrix: [[1,2,3],[4,5,6],[7,8,9]]
M = None  # your code here

# element at row 1, column 2 (0-indexed) -- expected: 6
element = None  # your code here

# entire second row (0-indexed) -- expected: [4, 5, 6]
row = None  # your code here

# entire first column -- expected: [1, 4, 7]
col = None  # your code here

print(f'matrix:\n{M}')
print(f'element at [1,2]: {element}')
print(f'row 1: {row}')
print(f'col 0: {col}')
print(f'shape: {M.shape}')

# %% [markdown]
# Task 4 - Vector Operations
#
# Perform vector addition, subtraction, scalar multiplication, and a linear combination.
# These are the two fundamental vector space operations: scaling and addition.

# %%
import numpy as np

u = np.array([1.0, 2.0, 3.0])
v = np.array([4.0, 5.0, 6.0])
s = 3.0

vec_sum  = None  # u + v
vec_diff = None  # u - v
scaled   = None  # s * u
lin_comb = None  # 2*u + 3*v

print(f'u + v   = {vec_sum}')
print(f'u - v   = {vec_diff}')
print(f's * u   = {scaled}')
print(f'2u + 3v = {lin_comb}')

# %% [markdown]
# Task 5 - Transpose
#
# Compute the transpose of a matrix.
# Transposing swaps rows and columns: element at [i, j] moves to [j, i].

# %%
import numpy as np

A = np.array([[1, 2, 3],
              [4, 5, 6]])  # shape (2, 3)

# transpose A -- result should have shape (3, 2)
A_T = None  # your code here

print(f'A shape  : {A.shape}')
print(f'A:\n{A}')
print(f'A_T shape: {A_T.shape}')
print(f'A_T:\n{A_T}')

# transpose a column vector (4,1) to a row vector (1,4)
col_vec = np.array([[10], [20], [30], [40]])
row_vec = None  # your code here

print(f'\ncol_vec shape: {col_vec.shape}')
print(f'row_vec shape: {row_vec.shape}')

# %% [markdown]
# Task 6 - Dot Product
#
# Compute the dot product of two vectors using three different methods.
# Dot product: sum of element-wise products. The result is a single scalar.

# %%
import numpy as np

a = np.array([1.0, 3.0, 5.0])
b = np.array([2.0, 4.0, 6.0])

# method 1: np.dot
dot_1 = None  # your code here

# method 2: @ operator
dot_2 = None  # your code here

# method 3: manual loop (provided for reference)
dot_manual = sum(a[i] * b[i] for i in range(len(a)))

print(f'np.dot : {dot_1}')
print(f'@ op   : {dot_2}')
print(f'manual : {dot_manual}')
print(f'all equal: {np.isclose(float(dot_1), float(dot_2)) and np.isclose(float(dot_1), dot_manual)}')

# %% [markdown]
# Task 7 - Element-wise Operations
#
# Perform element-wise multiplication, addition, and square root.
# Element-wise ops apply the operation to corresponding positions, not matrix multiplication.

# %%
import numpy as np

A = np.array([[1.0, 2.0], [3.0, 4.0]])
B = np.array([[5.0, 6.0], [7.0, 8.0]])

# element-wise multiplication (Hadamard product, NOT matmul)
C = None  # A * B

# element-wise addition
D = None  # A + B

# element-wise square root of A
E = None  # np.sqrt(A)

print(f'A * B (element-wise):\n{C}')
print(f'A + B:\n{D}')
print(f'sqrt(A):\n{E}')

# %% [markdown]
# Task 8 - Reshape
#
# Reshape arrays into different shapes without changing the data.
# Total number of elements must remain the same across any reshape.

# %%
import numpy as np

v = np.arange(1, 13)  # [1, 2, ..., 12], shape (12,)
print(f'original: shape={v.shape}, values={v}')

# reshape to (3, 4)
M1 = None  # your code here
print(f'\n(3, 4):\n{M1}')

# reshape to (2, 6)
M2 = None  # your code here
print(f'\n(2, 6):\n{M2}')

# reshape to (2, 2, 3) -- creates a 3D tensor
T = None  # your code here
print(f'\n(2, 2, 3):\n{T}')

# flatten back to 1D using .flatten() or .ravel()
flat = None  # your code here
print(f'\nflattened: {flat}')

# %% [markdown]
# Task 9 - L2 Norm
#
# Compute the L2 (Euclidean) norm of a vector, then normalise it.
# L2 norm = sqrt(sum of squares). Normalising gives a unit vector (length 1) in the same direction.

# %%
import numpy as np

v = np.array([3.0, 4.0, 0.0])

# compute L2 norm manually: sqrt(sum of squares)  -- expected: 5.0
norm_manual = None  # your code here

# compute using np.linalg.norm
norm_numpy = None  # your code here

# normalise: divide the vector by its norm
v_normalised = None  # your code here

print(f'vector        : {v}')
print(f'L2 manual     : {norm_manual}')
print(f'L2 numpy      : {norm_numpy}')
print(f'normalised    : {v_normalised}')
print(f'norm of unit  : {np.linalg.norm(v_normalised):.4f}  (should be 1.0)')

# %% [markdown]
# Task 10 - Matrix Multiplication
#
# Compute the matrix product of two matrices.
# For A (m x k) and B (k x n), the result C = A @ B has shape (m x n).
# The inner dimensions must match. Matrix multiplication is not element-wise.

# %%
import numpy as np

A = np.array([[1, 2],
              [3, 4],
              [5, 6]])   # shape (3, 2)

B = np.array([[7,  8,  9],
              [10, 11, 12]])  # shape (2, 3)

# compute A @ B using np.matmul -- result shape should be (3, 3)
C1 = None  # your code here

# compute the same using the @ operator
C2 = None  # your code here

print(f'A shape: {A.shape}')
print(f'B shape: {B.shape}')
print(f'C shape: {C1.shape}')
print(f'A @ B:\n{C1}')
print(f'results match: {np.allclose(C1, C2)}')

# also compute B @ A -- result shape should be (2, 2)
D = None  # your code here
print(f'\nB @ A shape: {D.shape}')
print(f'B @ A:\n{D}')
